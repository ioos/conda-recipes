# %%
import iris
import warnings


with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    cubes = iris.load_raw("http://omgsrv1.meas.ncsu.edu:8080/thredds/dodsC/fmrc/sabgom/"
                          "SABGOM_Forecast_Model_Run_Collection_best.ncd")

# %%
print(cubes)
# Out:
# 0: grid type logical switch / (no_unit) (-- : 64)
# 1: chlorophyll concentration / (unknown) (time: 312; ocean_s_coordinate_g1: 36; -- : 320; -- : 440)
# 2: mask on V-points / (1)              (-- : 319; -- : 440)
# 3: mask on U-points / (1)              (-- : 320; -- : 439)
# 4: tracers outflow, nudging inverse time scale / (second-1) (-- : 4; -- : 14)
# 5: phytoplankton concentration / (unknown) (time: 312; ocean_s_coordinate_g1: 36; -- : 320; -- : 440)
# 6: mask on RHO-points / (1)            (-- : 320; -- : 440)
# 7: vertically integrated v-momentum component / (meter second-1) (time: 312; -- : 319; -- : 440)
# 8: nonlinear model Laplacian mixing coefficient for tracers / (meter2 second-1) (-- : 14)
# 9: free-surface inflow, nudging inverse time scale / (second-1) (-- : 4)
# 10: background vertical mixing coefficient for tracers / (meter2 second-1) (-- : 14)
# 11: 3D momentum inflow, nudging inverse time scale / (second-1) (-- : 4)
# 12: 2D momentum outflow, nudging inverse time scale / (second-1) (-- : 4)
# 13: eastward_sea_water_velocity_assuming_no_tide / (meter second-1) (time: 312; ocean_s_coordinate_g1: 36; -- : 320; -- : 439)
# 14: nitrate concentration / (unknown)   (time: 312; ocean_s_coordinate_g1: 36; -- : 320; -- : 440)
# 15: curvilinear coordinate metric in ETA / (meter-1) (-- : 320; -- : 440)
# 16: 2D momentum inflow, nudging inverse time scale / (second-1) (-- : 4)
# 17: curvilinear coordinate metric in XI / (meter-1) (-- : 320; -- : 440)
# 18: 3D momentum outflow, nudging inverse time scale / (second-1) (-- : 4)
# 19: zooplankton concentration / (unknown) (time: 312; ocean_s_coordinate_g1: 36; -- : 320; -- : 440)
# 20: tracer point sources and simck activation switch / (1) (-- : 14)
# 21: ammonium concentration / (unknown)  (time: 312; ocean_s_coordinate_g1: 36; -- : 320; -- : 440)
# 22: mask on psi-points / (1)            (-- : 319; -- : 439)
# 23: angle between XI-axis and EAST / (radians) (-- : 320; -- : 440)
# 24: free-surface outflow, nudging inverse time scale / (second-1) (-- : 4)
# 25: Tracers nudging/relaxation inverse time scale / (day-1) (-- : 14)
# 26: sea_water_potential_temperature / (Celsius) (time: 312; ocean_s_coordinate_g1: 36; -- : 320; -- : 440)
# 27: Coriolis parameter at RHO-points / (second-1) (-- : 320; -- : 440)
# 28: sea_water_salinity / (1)            (time: 312; ocean_s_coordinate_g1: 36; -- : 320; -- : 440)
# 29: vertically integrated u-momentum component / (meter second-1) (time: 312; -- : 320; -- : 439)
# 30: vertical momentum component / (meter second-1) (time: 312; ocean_s_coordinate_g1: 37; -- : 320; -- : 440)
# 31: northward_sea_water_velocity_assuming_no_tide / (meter second-1) (time: 312; ocean_s_coordinate_g1: 36; -- : 319; -- : 440)
# 32: forecast_period / (hours since 2015-09-01T00:00:00Z) (time: 312)
# 33: tracers inflow, nudging inverse time scale / (second-1) (-- : 4; -- : 14)

# %%
cube = cubes.extract_strict("sea_water_potential_temperature")

print(cube)
# Out:
# sea_water_potential_temperature               (time: 312; ocean_s_coordinate_g1: 36; -- : 320; -- : 440)
#      Dimension coordinates:
#           time                                             x                           -        -         -
#           ocean_s_coordinate_g1                            -                           x        -         -
#      Auxiliary coordinates:
#           forecast_reference_time                          x                           -        -         -
#           sea_surface_height                               x                           -        x         x
#           S-coordinate stretching curves at RHO-points     -                           x        -         -
#           bathymetry at RHO-points                         -                           -        x         x
#           latitude                                         -                           -        x         x
#           longitude                                        -                           -        x         x
#      Derived coordinates:
#           sea_surface_height_above_reference_ellipsoid     x                           x        x         x
#      Scalar coordinates:
#           S-coordinate parameter, critical depth: 5.0 meter
#      Attributes:
#           CPP_options: SABGOM, ADD_FSOBC, ADD_M2OBC, ANA_BPFLUX, ANA_BSFLUX, ANA_BTFLUX, ANA_SPFLUX,...
#           Conventions: CF-1.4, _Coordinates
#           DODS.strlen: 0
#           DODS_EXTRA.Unlimited_Dimension: ocean_time
#           _CoordSysBuilder: ucar.nc2.dataset.conv.CF1Convention
#           ana_file: ROMS/Functionals/ana_btflux.h, ROMS/Functionals/ana_nudgcoef.h, ROMS/F...
#           bio_file: ROMS/Nonlinear/Biology/fennel.h
#           bpar_file: /home/omg/autosabgom/bioFasham_038_Katja.in.U3C4
#           bry_file: /gpfs_share/omg/omg/autosabgom/in/ncoda_bry_20150930.nc
#           cdm_data_type: GRID
#           clm_file: /gpfs_share/omg/omg/autosabgom/in/ncoda_clm_20150930.nc
#           code_dir: /he_data/he/zxue/COAWST411
#           compiler_command: /usr/local/apps/mpich/x86_64/pgi105/mx127..7/bin/mpif90
#           compiler_flags: -fastsse   -Kieee -fastsse -Mipa=fast -tp k8-64 -Mfree
#           compiler_system: pgi
#           cpu: x86_64
#           dia_file: /gpfs_share/omg/autosabgom/out/dia_20150930.nc
#           featureType: GRID
#           field: temperature, scalar, series
#           file: /gpfs_share/omg/autosabgom/out/his_20150930_0002.nc
#           format: netCDF-3 classic file
#           frc_file_01: /gpfs_share/omg/omg/autosabgom/in/nomads_forc_20150930.nc
#           frc_file_02: /gpfs_share/omg/omg/autosabgom/in/SABGOM.OTIS.Ref18581117.8Cons
#           frc_file_03: /gpfs_share/omg/omg/autosabgom/in/sabgom_river_79_clm_2014_2015.nc
#           grd_file: /gpfs_share/omg/omg/autosabgom/in/sabgom_grd.nc.Etopo2.LP.r1_5.filled
#           header_dir: /he_data/he/zxue/Projects/SABGOM_BIO
#           header_file: mch_bio_nf.h
#           his_base: /gpfs_share/omg/autosabgom/out/his_20150930
#           history: ROMS/TOMS, Version 3.4, Wednesday - September 30, 2015 -  2:50:37 AM ;...
#           ini_file: /gpfs_share/omg/omg/autosabgom/in/ncoda_ini_20150930.nc
#           location: Proto fmrc:SABGOM_Forecast_Model_Run_Collection
#           os: Linux
#           rst_file: /gpfs_share/omg/autosabgom/out/rst_20150930.nc
#           script_file: /home/omg/autosabgom/sabgom_20150930.in
#           spos_file: /home/omg/autosabgom/stations.in
#           sta_file: /gpfs_share/omg/autosabgom/out/sta_20150930.nc
#           svn_rev: 412M
#           svn_url: https://www.myroms.org/svn/omlab/branches/jcwarner
#           tiling: 008x004
#           time: ocean_time
#           title: ROMS/TOMS 3.0 - South-Atlantic Bight and Gulf of Mexico
#           type: ROMS/TOMS history file

# %%
c = cube[-1, -1, ...] # Last time step, surface, all x,y points.

# %%
import numpy.ma as ma

c.data = ma.masked_invalid(c.data)

# %%
# %matplotlib inline

import iris.plot as iplt

cs = iplt.pcolormesh(c)
